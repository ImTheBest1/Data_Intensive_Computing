# %% [markdown]
# # Miaomiao Zhang, UBID: 50067071
# # Partner: Xinyu Chen, UBID: 50101273

# %% [markdown]
# ### 1. Basic R Commands

# %%
foo <- 2
bar <- 4

# %%
foo + bar
# Out:
# [1] 6

# %%
result <- foo + bar

# %%
result
# Out:
# [1] 6

# %%
list <- c(2, 4, 6, 8)

# %%
list [2]
# Out:
# [1] 4

# %%
print (list[2])
# Out:
# [1] 4

# %%
list [1]
# Out:
# [1] 2

# %%
print (list[0])
# Out:
# numeric(0)

# %%
list1 <- c(1, 3, 5, 9, 3)

# %%
print (list1[0])
# Out:
# numeric(0)

# %%
list[5]
# Out:
# [1] NA

# %%
print (list[5])
# Out:
# [1] NA

# %%
10 / 2
# Out:
# [1] 5

# %%
10 ^2
# Out:
# [1] 100

# %%
4 * 5
# Out:
# [1] 20

# %%
1 + 6
# Out:
# [1] 7

# %%
2 == 0
# Out:
# [1] FALSE

# %%
(2 + 2) == 4
# Out:
# [1] TRUE

# %%
T == TRUE
# Out:
# [1] TRUE

# %%
F && T
# Out:
# [1] FALSE

# %%
F || TRUE
# Out:
# [1] TRUE

# %%
# Try creating a vector called “vect” with several numbers. 
# Multilply the vector by 2 (i.e. vect * 2) and press Enter.

# %%
vect <- c(2, 4, 6, 8, 10)
vect1 <- vect * 2
print (vect1)
# Out:
# [1]  4  8 12 16 20

# %%
# sqrt(vect)

# %%
vect2 <- sqrt(vect)
print (vect2)
# Out:
# [1] 1.414214 2.000000 2.449490 2.828427 3.162278

# %%
names(vect) = c("1st", "2nd", "3rd", "4th", "5th")

# %%
vect
# Out:
# 1st 2nd 3rd 4th 5th
#   2   4   6   8  10

# %%
print (vect)
# Out:
# 1st 2nd 3rd 4th 5th
#   2   4   6   8  10

# %%
vect["2nd"] <- 20

# %%
vect
# Out:
# 1st 2nd 3rd 4th 5th
#   2  20   6   8  10

# %%
demo(graphics)
# Out:
# 	demo(graphics)
# 	---- ~~~~~~~~
#
# > #  Copyright (C) 1997-2009 The R Core Team
# >
# > require(datasets)
#
# > require(grDevices); require(graphics)
#
# > ## Here is some code which illustrates some of the differences between
# > ## R and S graphics capabilities.  Note that colors are generally specified
# > ## by a character string name (taken from the X11 rgb.txt file) and that line
# > ## textures are given similarly.  The parameter "bg" sets the background
# > ## parameter for the plot and there is also an "fg" parameter which sets
# > ## the foreground color.
# >
# >
# > x <- stats::rnorm(50)
#
# > opar <- par(bg = "white")
#
# > plot(x, ann = FALSE, type = "n")
#
# > abline(h = 0, col = gray(.90))
#
# > lines(x, col = "green4", lty = "dotted")
#
# > points(x, bg = "limegreen", pch = 21)
#
# > title(main = "Simple Use of Color In a Plot",
# +       xlab = "Just a Whisper of a Label",
# +       col.main = "blue", col.lab = gray(.8),
# ...

# %% [markdown]
# # 11.  Basic plots: Line graphs, histograms, box plots: Save the images generated as pictures(.png)

# %% [markdown]
# ### problem1:  Define two synthetic vectors of data representing sales over 12 months for 2 items. Compare the two using lines graphs. (Discussion; Run the code multiple time and see randomness of the second set of data..)

# %%
sales1 <- c(12,14,16,29,30,45,19,20,16,19,34,20)
sales2 <- rpois(12,34)  # random numbers, poisson distribution, mean at 34,12 numbers par
print (sales2)

# bg == background
par(bg = "cornsilk")
# type is the option apply to the graph, 
# types reference website: https://www.statmethods.net/graphs/images/lines0.png
# Plotting Symbols, pch == print character, can use with type
# plot(sales1, col="blue", type = "o", pch = 2, ylim=c(0,100), xlab="Month", ylab="Sales" )
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

# line type: lty, range from 1-6
lines(sales2, type="o", pch=22, lty=2, col="red")
# grid: https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/grid.html
# grid(nx = NULL, ny = NULL)
grid(nx=NA, ny=NULL)
# grid(6, 6)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
#  [1] 31 25 37 30 42 30 30 40 44 28 31 35
# Plot with title “Sales by Month”

# %% [markdown]
# ### Problem 2: The sales data is available in a table in a text file. Read it in and draw a side-by- side histogram to compare the performance. (Discussion)

# %%
sales<-read.table("/Users/mmz/Desktop/Spring2018/CSE587_Data_Intentensive_Computing/Homework/PA1/salesdata.txt", header=T)

# %%
# to verify that data has been read
sales
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23

# %%
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             gfd
# Out:
# Plot with title “Sales Data”

# %% [markdown]
# ### Problem 3: Use boxplot to compare the two sales data. (Discussion: How will you interpret the graph visualization?)

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# ### Problem 4: Download csv data from the web and analyze using the methods above.
# Download the historical prices for any two or more sticks of your choice and compare. We will do it for Apple (AAPL) and Facebook (FB) for one year.

# %%
fb1<-read.csv("/Users/mmz/Desktop/Spring2018/CSE587_Data_Intentensive_Computing/Homework/PA1/FB.csv")
fb1
# Out:
#    Date       Open   High   Low    Close  Adj.Close Volume
# 1  2017-11-06 178.56 180.45 178.31 180.17 180.17    13312700
# 2  2017-11-07 180.50 180.75 178.96 180.25 180.25    12928200
# 3  2017-11-08 179.79 180.35 179.11 179.56 179.56    10494100
# 4  2017-11-09 178.31 179.40 177.09 179.30 179.30    12610300
# 5  2017-11-10 178.35 179.10 177.96 178.46 178.46    11070200
# 6  2017-11-13 177.50 179.04 177.30 178.77 178.77     9523400
# 7  2017-11-14 178.13 178.97 177.18 178.07 178.07     9585900
# 8  2017-11-15 176.66 178.57 176.40 177.95 177.95    10253700
# 9  2017-11-16 178.76 179.83 178.50 179.59 179.59    15607600
# 10 2017-11-17 179.30 179.98 178.90 179.00 179.00    13018000
# 11 2017-11-20 178.87 179.50 178.10 178.74 178.74    10052400
# 12 2017-11-21 179.15 181.89 178.99 181.86 181.86    14504000
# 13 2017-11-22 181.30 181.73 180.44 180.87 180.87    10376300
# 14 2017-11-24 180.40 183.15 180.29 182.78 182.78     9426300
# ...

# %%
aapl1<-read.csv("/Users/mmz/Desktop/Spring2018/CSE587_Data_Intentensive_Computing/Homework/PA1/AAPL.csv")
aapl1
# Out:
#    Date       Open   High   Low    Close  Adj.Close Volume
# 1  11/6/2017  172.37 174.99 171.72 174.25 173.6258  35026300
# 2  11/7/2017  173.91 175.25 173.60 174.81 174.1838  24361500
# 3  11/8/2017  174.66 176.24 174.33 176.24 175.6087  24409500
# 4  11/9/2017  175.11 176.10 173.14 175.88 175.2500  29482600
# 5  11/10/2017 175.11 175.38 174.27 174.67 174.6700  25145500
# 6  11/13/2017 173.50 174.50 173.40 173.97 173.9700  16982100
# 7  11/14/2017 173.04 173.48 171.18 171.34 171.3400  24782500
# 8  11/15/2017 169.97 170.32 168.38 169.08 169.0800  29158100
# 9  11/16/2017 171.18 171.87 170.30 171.10 171.1000  23637500
# 10 11/17/2017 171.04 171.39 169.64 170.15 170.1500  21899500
# 11 11/20/2017 170.29 170.56 169.56 169.98 169.9800  16262400
# 12 11/21/2017 170.78 173.70 170.78 173.14 173.1400  25131300
# 13 11/22/2017 173.36 175.00 173.05 174.96 174.9600  25588900
# 14 11/24/2017 175.10 175.50 174.65 174.97 174.9700  14026700
# ...

# %%
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(160,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title “Histogram of aapl1$Adj.Close”

# %% [markdown]
# ### Problem 5: Data sets available with R: R community has created a lot of data for others to use. Examine the data sets already available with R. data(), attach(),detach(), head(), summary()

# %%
# Access existing data sets in R
data()

# %%
# This means that the database is searched by R when evaluating a variable, so objects in the database can be accessed by simply giving their names
#?attach
BOD
data("BOD")
typeof("BOD") 
attach(BOD)
head(BOD)
summary(BOD) # summary is a generic function used to produce result summaries of the results of various model fitting functions
detach(BOD)  # after analysis remove the data from the memory
# Out:
#   Time demand
# 1 1     8.3
# 2 2    10.3
# 3 3    19.0
# 4 4    16.0
# 5 5    15.6
# 6 7    19.8
# [1] "character"
# The following objects are masked from BOD (pos = 3):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 4):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 5):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 6):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 7):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 8):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 9):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 10):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 11):
#
#     demand, Time
#
# The following objects are masked from BOD (pos = 12):
#
#     demand, Time
#   Time demand
# 1 1     8.3
# 2 2    10.3
# 3 3    19.0
# 4 4    16.0
# 5 5    15.6
# 6 7    19.8
# ...

# %%
library (help=datasets)

# %% [markdown]
# ### Problem 6: Accessing external APIs

# %%
library("ggmap")

install.packages("maptools")
library("maptools")

install.packages("maps")
library(maps)
# Out:
# The downloaded binary packages are in
# 	/var/folders/7p/j7p337hn7g18q87ksvd7fpr80000gn/T//Rtmp4iZpoc/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/7p/j7p337hn7g18q87ksvd7fpr80000gn/T//Rtmp4iZpoc/downloaded_packages

# %%
visited <- c("SFO", "Chennai", "London", "Melbourne", "Johannesbury, SA")

ll.visited <- geocode(visited)
# a <- geocode(visited)

visit.x <- ll.visited$lon
visit.y <- ll.visited$lat

map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "SFO"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chennai&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=London&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,%20SA&sensor=false
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
cities <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.cities <- geocode(cities)
visited.x <- ll.cities$lon
visited.y <- ll.cities$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visited.x,visited.y, col="yellow", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas,%20TX&sensor=false
# plot without title

# %% [markdown]
# ### Problem 7: we will conclude the “base” graphics capabilities of R package with a very old but popular data set available in R: mtcars (motor trends car package). Attach and explore mtcars. Draw scatter plots of the dependent variables (i) 5 variables (ii) 4 variables.

# %%
install.packages("lattice")
library("lattice")
# Out:
# The downloaded binary packages are in
# 	/var/folders/7p/j7p337hn7g18q87ksvd7fpr80000gn/T//Rtmp4iZpoc/downloaded_packages

# %%
splom(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
splom(mtcars[c(1,3,4,6)], main="MTCARS Data")
# Out:
# plot without title
# plot without title

# %%
splom(mtcars[c(1,3,4,6)], col=rainbow(4),main="MTCARS Data")
# Out:
# plot without title

# %%
#Another data set: “rock” 
splom(rock[c(1,2,3,4)], main="ROCK Data")
# Out:
# plot without title

# %% [markdown]
# ### Problem 8: Working with ggplot2 package (), loading a package, installing package. Object- oriented and incremental additions (extensibility) are special features of this package. We can layer the commands to a base plot

# %%
# loading a package
library(ggplot2)

# %%
df <- data.frame(gp = factor(rep(letters[1:3], each = 10)),y = rnorm(30))
ds <- plyr::ddply(df, "gp", plyr::summarise, mean = mean(y), sd = sd(y))
ggplot(df, aes(gp, y)) + geom_point() + geom_point(data = ds, aes(y = mean), colour = 'red', size = 3)
# Out:
# plot without title

# %%
ggplot() + geom_point(data = df, aes(gp, y)) + geom_point(data = ds, aes(gp, mean), colour = 'red', size = 3) + geom_errorbar(
    data = ds, aes(gp, mean, ymin = mean - sd, ymax = mean + sd), colour = 'red', width = 0.4)
# Out:
# Warning message:
# “Ignoring unknown aesthetics: y”
# plot without title
